# %%
import pandas as pd

# %%
data=pd.read_excel(r"E:\pandas\L2G8810_Lidar_KPI_Test_Report_OD_HIL_I480_V3_ER_GER_KAFAS_GT_Part3.xlsx",sheet_name= "False Positives", header=61)

# %%
data
# Out:
#                                          RecordingName  \
# 0    LIDAR_LJ02772_20240118_113255_I480-PDX-009-048...
# 1    LIDAR_LJ02772_20240118_113255_I480-PDX-009-048...
# 2    LIDAR_LJ02766_20240202_151013_I480-PDX-009-048...
# 3    LIDAR_LJ02772_20240118_101131_I480-PDX-009-048...
# 4    LIDAR_LJ02772_20240118_121322_I480-PDX-009-048...
# ..                                                 ...
# 97   LIDAR_LJ02772_20240118_115309_I480-PDX-009-048...
# 98   LIDAR_LJ02772_20240118_134101_I480-PDX-009-048...
# 99   LIDAR_LJ02772_20240118_093104_I480-PDX-009-048...
# 100  LIDAR_LJ02772_20240118_093104_I480-PDX-009-048...
# 101  LIDAR_LJ02772_20240118_134101_I480-PDX-009-048...
#
#                       sequenceName  \
# 0    LIDAR_LJ02772_20240118_113255
# 1    LIDAR_LJ02772_20240118_113255
# 2    LIDAR_LJ02766_20240202_151013
# 3    LIDAR_LJ02772_20240118_101131
# 4    LIDAR_LJ02772_20240118_121322
# ..                             ...
# 97   LIDAR_LJ02772_20240118_115309
# ...

# %%
data[["sequenceName"]]
# Out:
#                       sequenceName
# 0    LIDAR_LJ02772_20240118_113255
# 1    LIDAR_LJ02772_20240118_113255
# 2    LIDAR_LJ02766_20240202_151013
# 3    LIDAR_LJ02772_20240118_101131
# 4    LIDAR_LJ02772_20240118_121322
# ..                             ...
# 97   LIDAR_LJ02772_20240118_115309
# 98   LIDAR_LJ02772_20240118_134101
# 99   LIDAR_LJ02772_20240118_093104
# 100  LIDAR_LJ02772_20240118_093104
# 101  LIDAR_LJ02772_20240118_134101
#
# [102 rows x 1 columns]

# %%
data.isna().sum()
# Out:
# RecordingName                                                                                   0
# sequenceName                                                                                    0
# RecogLidarObjectlist_Objectlist_object_list_summary_id                                          0
# VelocityAndVehicleConditionProvision_velocityVehicle_velocityvehiclecog_velocityvehiclecog      0
# OD_OM_timestamp                                                                                 0
#                                                                                              ...
# Sub_category                                                                                   78
# Comments                                                                                      101
# Found Both In Iteration and Base                                                                0
# Found Just In Base                                                                              0
# ...

# %%
data.isna()
# Out:
#      RecordingName  sequenceName  \
# 0            False         False
# 1            False         False
# 2            False         False
# 3            False         False
# 4            False         False
# ..             ...           ...
# 97           False         False
# 98           False         False
# 99           False         False
# 100          False         False
# 101          False         False
#
#      RecogLidarObjectlist_Objectlist_object_list_summary_id  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 97                                               False
# 98                                               False
# ...

# %%
data['Root_cause'].isna().sum()
# Out:
# 78

# %%
data['sequenceName'].dtypes
# Out:
# dtype('O')

# %%
df2=data[["DUT_Movement","DUT_Age","Root_cause","Sub_category","OD_OM_timestamp","sequenceName"]]

# %%
df2
# Out:
#      DUT_Movement  DUT_Age  Root_cause  \
# 0               0     1272   DUT error
# 1               1      494   DUT error
# 2               0       76         NaN
# 3               0      691    GT error
# 4               0     2066  Data error
# ..            ...      ...         ...
# 97            255      250   DUT error
# 98              0      275         NaN
# 99              0       15         NaN
# 100             0       15         NaN
# 101             0      227  Data error
#
#                                      Sub_category  OD_OM_timestamp  \
# 0                  BB matching static object+20cm         22603907
# 1                  BB matching static object+20cm         22719568
# 2                                             NaN         26562043
# 3               GT object of incorrect dimensions         17568898
# 4     Out of ODD (Insufficient pre-label details)         24602801
# ..                                            ...              ...
# ...

# %%
df2['Root_cause'].isna()
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 97     False
# 98      True
# 99      True
# 100     True
# 101    False
# Name: Root_cause, Length: 102, dtype: bool

# %%
df2['Root_cause'].isna().sum()
# Out:
# 78

# %%
df2['Root_cause'].fillna('No Error',inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15464\1576915410.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Root_cause'].fillna('No Error',inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15464\1576915410.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df2
# Out:
#      DUT_Movement  DUT_Age  Root_cause  \
# 0               0     1272   DUT error
# 1               1      494   DUT error
# 2               0       76    No Error
# 3               0      691    GT error
# 4               0     2066  Data error
# ..            ...      ...         ...
# 97            255      250   DUT error
# 98              0      275    No Error
# 99              0       15    No Error
# 100             0       15    No Error
# 101             0      227  Data error
#
#                                      Sub_category  OD_OM_timestamp  \
# 0                  BB matching static object+20cm         22603907
# 1                  BB matching static object+20cm         22719568
# 2                                             NaN         26562043
# 3               GT object of incorrect dimensions         17568898
# 4     Out of ODD (Insufficient pre-label details)         24602801
# ..                                            ...              ...
# ...

# %%
df2.dropna(inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15464\1761232742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)

# %%
df2
# Out:
#      DUT_Movement  DUT_Age  Root_cause  \
# 0               0     1272   DUT error
# 1               1      494   DUT error
# 3               0      691    GT error
# 4               0     2066  Data error
# 8             255      373   DUT error
# 12              0      131  Data error
# 17              0       51   DUT error
# 20              0      139  Data error
# 27              0     2955  Data error
# 28              0     2955  Data error
# 29              0     6488   DUT error
# 31              0      666   DUT error
# 38              0      297   DUT error
# 46              1      143   DUT error
# 47              0       49  Data error
# 49            255      282   DUT error
# 50              1      122    GT error
# 53              1      122    GT error
# 57              0     1318   DUT error
# 59              0      348  Data error
# 63              0       69   DUT error
# 80            255       84   DUT error
# 97            255      250   DUT error
# ...

# %%
df2.size
# Out:
# 144

# %%
df2.shape
# Out:
# (24, 6)

# %%
df2["DUT_Age"].mean()
# Out:
# 899.6666666666666

# %%
df2["DUT_Age"].median()
# Out:
# 289.5

# %%
df2["DUT_Age"].mode()[0]
# Out:
# 122

# %%
df2["Root_cause"].unique()
# Out:
# array(['DUT error', 'GT error', 'Data error'], dtype=object)

# %%
df2["Root_cause"].unique()
# Out:
# array(['DUT error', 'GT error', 'Data error'], dtype=object)

# %%
df2["Root_cause"].value_counts()
# Out:
# Root_cause
# DUT error     13
# Data error     8
# GT error       3
# Name: count, dtype: int64

# %%
a = df2['Sub_category'] == 'Out of ODD (Insufficient pre-label details)'
b = df2['Sub_category'] == 'FP due to Overtaken object of Low Visibility'

df2[a | b]
# Out:
#      DUT_Movement  DUT_Age  Root_cause  \
# 4               0     2066  Data error
# 12              0      131  Data error
# 20              0      139  Data error
# 27              0     2955  Data error
# 28              0     2955  Data error
# 47              0       49  Data error
# 59              0      348  Data error
# 101             0      227  Data error
#
#                                      Sub_category  OD_OM_timestamp  \
# 4     Out of ODD (Insufficient pre-label details)         24602801
# 12   FP due to Overtaken object of Low Visibility         26565710
# 20   FP due to Overtaken object of Low Visibility         23225475
# 27    Out of ODD (Insufficient pre-label details)         16637679
# 28    Out of ODD (Insufficient pre-label details)         16637679
# 47   FP due to Overtaken object of Low Visibility         23134809
# 59   FP due to Overtaken object of Low Visibility         30014844
# 101  FP due to Overtaken object of Low Visibility         29969979
#
# ...
